# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/dell/Desktop/data_2.csv',encoding = 'gbk')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 90 columns):
# Unnamed: 0                                    4754 non-null int64
# custid                                        4754 non-null int64
# trade_no                                      4754 non-null object
# bank_card_no                                  4754 non-null object
# low_volume_percent                            4752 non-null float64
# middle_volume_percent                         4752 non-null float64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4751 non-null float64
# trans_activity_month                          4752 non-null float64
# trans_activity_day                            4752 non-null float64
# transd_mcc                                    4752 non-null float64
# trans_days_interval_filter                    4746 non-null float64
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0   custid                          trade_no bank_card_no  \
# 0           5  2791858  20180507115231274000000023057383          卡号1
# 1          10   534047  20180507121002192000000023073000          卡号1
# 2          12  2849787  20180507125159718000000023114911          卡号1
# 3          13  1809708  20180507121358683000000388283484          卡号1
# 4          14  2499829  20180507115448545000000388205844          卡号1
# 5          15   518072  20180507121233054000000388275132          卡号1
# 6          16  1205125  20180507121931540000000388298915          卡号1
# 7          18  1129897  20180507124659235000000023105807          卡号1
# 8          20  2599411  20180507115855621000000388224458          卡号1
# 9          26  1413051  20180504155156296000000021138084          卡号1
#
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# ...

# %% [markdown]
# #### 数据类型相关

# %%
data.select_dtypes(include=object)#.head(20)
# Out:
#                               trade_no bank_card_no reg_preference_for_trad  \
# 0     20180507115231274000000023057383          卡号1                    一线城市
# 1     20180507121002192000000023073000          卡号1                    一线城市
# 2     20180507125159718000000023114911          卡号1                    一线城市
# 3     20180507121358683000000388283484          卡号1                    三线城市
# 4     20180507115448545000000388205844          卡号1                    一线城市
# 5     20180507121233054000000388275132          卡号1                    三线城市
# 6     20180507121931540000000388298915          卡号1                    一线城市
# 7     20180507124659235000000023105807          卡号1                    一线城市
# 8     20180507115855621000000388224458          卡号1                    三线城市
# 9     20180504155156296000000021138084          卡号1                    一线城市
# 10    20180507123917136000000388381264          卡号1                    一线城市
# ...

# %%
data.trade_no.value_counts()
# Out:
# 20180507122334998000000388318858    1
# 20180507125214429000000388427753    1
# 20180507121947634000000388299994    1
# 20180507114913242000000388190783    1
# 20180507120719874000000388257180    1
# 20180507115346166000000023059023    1
# 20180507122117775000000388314541    1
# 20180507122447254000000388324108    1
# 20180504162022979000000381366693    1
# 20180504175838715000000381770864    1
# 20180504165423327000000381511386    1
# 20180504164121864000000381450944    1
# 20180507122831724000000388340056    1
# 20180507121210191000000023074069    1
# 20180507122420210000000388325624    1
# 20180507120831961000000388261289    1
# 20180504181852729000000381839960    1
# 20180507121958460000000388306145    1
# 20180507122835743000000388339049    1
# 20180504183350266000000021310490    1
# 20180504164639135000000381482387    1
# 20180504163922146000000381444739    1
# 20180507121730945000000023082786    1
# 20180507115458227000000388209305    1
# 20180504162314924000000381381277    1
# ...

# %%
data.bank_card_no.value_counts()
# Out:
# 卡号1    4754
# Name: bank_card_no, dtype: int64

# %%
data.reg_preference_for_trad.value_counts()
# Out:
# 一线城市    3403
# 三线城市    1064
# 境外       150
# 二线城市     131
# 其他城市       4
# Name: reg_preference_for_trad, dtype: int64

# %%
data.source.value_counts()
# Out:
# xs    4754
# Name: source, dtype: int64

# %%
data.id_name.value_counts()
# Out:
# 张龙       5
# 李杰       5
# 李明       5
# 张超       4
# 陈波       4
# 刘强       4
# 张伟       4
# 陈鹏       4
# 李波       4
# 张杰       3
# 陈洁       3
# 李鹏       3
# 杨浩       3
# 张旭       3
# 李栋       3
# 杨明       3
# 王帅       3
# 王剑       3
# 李博       3
# 张健       3
# 张强       3
# 张平       3
# 王强       3
# 王毅       3
# 刘凯       3
# 刘磊       3
# 陈成       2
# 陈锋       2
# 李海东      2
# 刘洋       2
#         ..
# 杨武园      1
# 陈阿平      1
# 蔡艺文      1
# 廖定威      1
# 吴奇娜      1
# 陈程       1
# 盛网健      1
# 朱传万      1
# 陈绍辉      1
# 王丽莎      1
# 王星       1
# 高祥       1
# 王臻       1
# 张国峰      1
# 王立峰      1
# 刘槽       1
# 叶锐龙      1
# 沈桂将      1
# 刘志勇      1
# 孙海霞      1
# 刘闲       1
# 刘兴昌      1
# 周京       1
# 王博伟      1
# 哈森其木格    1
# 黄抒婷      1
# 唐尚勇      1
# 王纯       1
# 林汉基      1
# 王立文      1
# Name: id_name, Length: 4309, dtype: int64

# %%
data.latest_query_time.value_counts()
# Out:
# 2018-04-14    423
# 2018-05-06    223
# 2018-05-05    214
# 2018-05-04    210
# 2018-05-02    204
# 2018-05-03    201
# 2018-04-13    177
# 2018-04-23    166
# 2018-04-28    139
# 2018-05-01    133
# 2018-04-26    132
# 2018-04-27    131
# 2018-04-29    129
# 2018-04-25    120
# 2018-04-30    116
# 2018-04-24    101
# 2018-04-21     90
# 2018-04-19     85
# 2018-04-16     81
# 2018-04-20     78
# 2018-04-22     74
# 2018-04-17     70
# 2018-04-15     69
# 2018-04-18     62
# 2018-04-02     48
# 2018-04-11     45
# 2018-04-10     39
# 2018-03-27     36
# 2018-04-05     33
# 2018-04-04     31
#              ...
# 2017-11-14      1
# 2017-11-20      1
# 2018-01-25      1
# 2018-02-20      1
# 2018-01-04      1
# 2017-12-31      1
# 2017-12-30      1
# 2017-09-05      1
# 2017-11-15      1
# 2017-10-22      1
# 2017-05-18      1
# 2017-09-18      1
# 2017-05-26      1
# 2017-07-09      1
# 2017-10-20      1
# 2017-11-03      1
# 2017-12-24      1
# 2018-02-24      1
# 2017-11-13      1
# ...

# %%
data.loans_latest_time.value_counts()
# Out:
# 2018-05-03    134
# 2018-05-04    133
# 2018-05-02    131
# 2018-05-06    123
# 2018-05-05    118
# 2018-04-30    112
# 2018-05-01    103
# 2018-04-28     92
# 2018-04-25     85
# 2018-04-29     83
# 2018-04-27     78
# 2018-04-24     74
# 2018-04-19     69
# 2018-04-26     67
# 2018-04-23     63
# 2018-04-20     62
# 2018-04-16     53
# 2018-04-14     51
# 2018-04-12     47
# 2018-04-22     46
# 2018-04-17     44
# 2018-04-18     43
# 2018-04-21     42
# 2018-04-11     42
# 2018-04-15     41
# 2018-03-15     40
# 2018-03-14     37
# 2018-04-10     36
# 2018-04-09     36
# 2018-04-08     35
#              ...
# 2017-09-26      1
# 2017-07-14      1
# 2017-09-07      1
# 2017-07-16      1
# 2017-06-15      1
# 2017-10-03      1
# 2017-09-22      1
# 2017-10-02      1
# 2017-08-02      1
# 2017-09-21      1
# 2017-11-03      1
# 2017-06-25      1
# 2017-10-22      1
# 2017-11-07      1
# 2017-08-22      1
# 2017-09-03      1
# 2017-09-25      1
# 2017-09-24      1
# 2017-09-27      1
# ...

# %%
data = data.drop(['trade_no','bank_card_no','source'],axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder
labe = LabelEncoder()

# %%
data.reg_preference_for_trad[data.reg_preference_for_trad.isna()==True] = '其他_1'
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# data.reg_preference_for_trad = data.astype('category')
data.reg_preference_for_trad = labe.fit_transform(data.reg_preference_for_trad)

# %%
data.reg_preference_for_trad.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: reg_preference_for_trad, dtype: int64

# %%
data.reg_preference_for_trad.value_counts()
# Out:
# 0    3403
# 1    1064
# 5     150
# 2     131
# 4       4
# 3       2
# Name: reg_preference_for_trad, dtype: int64

# %%
data.id_name[data.id_name.isna()==True] = '名字缺失'
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.id_name = labe.fit_transform(data.id_name)

# %%
data.id_name.value_counts()
# Out:
# 589     276
# 1815      5
# 1844      5
# 1419      5
# 1394      4
# 3966      4
# 349       4
# 1862      4
# 1165      4
# 3896      4
# 1288      3
# 1312      3
# 2062      3
# 2563      3
# 1174      3
# 2574      3
# 2038      3
# 1244      3
# 1943      3
# 2647      3
# 3898      3
# 309       3
# 1255      3
# 1741      3
# 424       3
# 1847      3
# 2523      3
# 1346      2
# 1410      2
# 1508      2
#        ...
# 3363      1
# 1314      1
# 3359      1
# 1310      1
# 3355      1
# 1306      1
# 3351      1
# 1302      1
# 3347      1
# 1298      1
# 3343      1
# 1294      1
# 3339      1
# 1290      1
# 3335      1
# 3331      1
# 1282      1
# 3327      1
# 1278      1
# 3323      1
# 1274      1
# 3319      1
# 1270      1
# 3315      1
# 1266      1
# 3311      1
# 1262      1
# 3307      1
# 1258      1
# 0         1
# Name: id_name, Length: 4310, dtype: int64

# %%
from datetime import datetime

# %%
data.latest_query_time = pd.to_datetime(data.latest_query_time)

# %%
# data.status[data.latest_query_time.isna()==True]
data.latest_query_time[data.latest_query_time.isna()==True]=pd.to_datetime('2000-01-01')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.latest_query_time
# Out:
# 0      2018-04-25
# 1      2018-05-03
# 2      2018-05-05
# 3      2018-05-05
# 4      2018-04-15
# 5      2018-05-04
# 6      2018-05-06
# 7      2000-01-01
# 8      2018-04-13
# 9      2018-04-16
# 10     2018-04-25
# 11     2018-04-06
# 12     2018-03-30
# 13     2018-04-24
# 14     2018-04-21
# 15     2018-05-03
# 16     2018-05-04
# 17     2018-04-28
# 18     2018-04-11
# 19     2018-04-25
# 20     2018-05-04
# 21     2018-04-30
# 22     2018-04-30
# 23     2018-04-25
# 24     2018-04-23
# 25     2018-04-13
# 26     2018-04-27
# 27     2018-04-17
# 28     2018-05-02
# 29     2000-01-01
#           ...
# 4724   2018-04-16
# 4725   2017-12-16
# 4726   2018-04-15
# 4727   2018-04-09
# 4728   2018-04-19
# 4729   2018-05-04
# 4730   2018-04-09
# 4731   2018-05-05
# 4732   2018-04-28
# 4733   2018-04-23
# 4734   2018-04-13
# 4735   2018-05-05
# 4736   2018-04-19
# 4737   2018-05-03
# 4738   2018-03-20
# 4739   2018-04-22
# 4740   2018-04-06
# 4741   2018-04-25
# 4742   2018-05-03
# ...

# %%
data.loans_latest_time = pd.to_datetime(data.loans_latest_time)
data.loans_latest_time[data.loans_latest_time.isna()==True]=pd.to_datetime('2000-01-01')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
d = pd.read_csv('C:/Users/dell/Desktop/data_2.csv',encoding = 'gbk')
c = d.select_dtypes(include=object)
c.columns
# Out:
# Index(['trade_no', 'bank_card_no', 'reg_preference_for_trad', 'source',
#        'id_name', 'latest_query_time', 'loans_latest_time'],
#       dtype='object')

# %%
d1 = d.select_dtypes(exclude=object)
d1.shape
# Out:
# (4754, 83)

# %%
d1.columns
# Out:
# Index(['Unnamed: 0', 'custid', 'low_volume_percent', 'middle_volume_percent',
#        'take_amount_in_later_12_month_highest',
#        'trans_amount_increase_rate_lately', 'trans_activity_month',
#        'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
#        'trans_days_interval', 'regional_mobility', 'student_feature',
#        'repayment_capability', 'is_high_user', 'number_of_trans_from_2011',
#        'first_transaction_time', 'historical_trans_amount',
#        'historical_trans_day', 'rank_trad_1_month', 'trans_amount_3_month',
#        'avg_consume_less_12_valid_month', 'abs',
#        'top_trans_count_last_1_month', 'avg_price_last_12_month',
#        'avg_price_top_last_12_valid_month', 'trans_top_time_last_1_month',
#        'trans_top_time_last_6_month', 'consume_top_time_last_1_month',
#        'consume_top_time_last_6_month', 'cross_consume_count_last_1_month',
#        'trans_fail_top_count_enum_last_1_month',
# ...

# %%
data.info()
# 'Unnamed: 0','custid',
# student_feature
# 'is_high_user'
# first_transaction_time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 87 columns):
# Unnamed: 0                                    4754 non-null int64
# custid                                        4754 non-null int64
# low_volume_percent                            4752 non-null float64
# middle_volume_percent                         4752 non-null float64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4751 non-null float64
# trans_activity_month                          4752 non-null float64
# trans_activity_day                            4752 non-null float64
# transd_mcc                                    4752 non-null float64
# trans_days_interval_filter                    4746 non-null float64
# trans_days_interval                           4752 non-null float64
# regional_mobility                             4752 non-null float64
# ...

# %%
# data.loc[:,'history_suc_fee':].head(3)
# Out:
#    history_suc_fee  history_fail_fee  latest_one_month_suc  \
# 0             37.0               7.0                   1.0
# 1             49.0               4.0                   2.0
# 2              2.0               2.0                   1.0
#
#    latest_one_month_fail  loans_long_time loans_latest_time  \
# 0                    0.0            341.0        2018-04-19
# 1                    1.0            353.0        2018-05-05
# 2                    1.0            157.0        2018-05-01
#
#    loans_credit_limit  loans_credibility_limit  loans_org_count_current  \
# 0              2200.0                     72.0                      9.0
# 1              2000.0                     74.0                     12.0
# 2              1500.0                     77.0                      2.0
#
#    loans_product_count  loans_max_limit  loans_avg_limit  \
# 0                 10.0           2900.0           1688.0
# 1                 12.0           3500.0           1758.0
# ...

# %%
data = data[['reg_preference_for_trad', 'id_name', 'latest_query_time', 'loans_latest_time','take_amount_in_later_12_month_highest',
      'is_high_user', 'historical_trans_amount', 'trans_amount_3_month','abs', 'avg_price_last_12_month',
      'max_cumulative_consume_later_1_month',  'pawns_auctions_trusts_consume_last_1_month', 'pawns_auctions_trusts_consume_last_6_month',            
      'repayment_capability',
              'number_of_trans_from_2011','low_volume_percent', 'middle_volume_percent',
       'trans_amount_increase_rate_lately', 'trans_activity_month',  'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
       'trans_days_interval', 'regional_mobility', 'student_feature',
       'first_transaction_time',  'historical_trans_day', 'rank_trad_1_month',
       'avg_consume_less_12_valid_month',  'top_trans_count_last_1_month', 
       'avg_price_top_last_12_valid_month', 'trans_top_time_last_1_month', 'trans_top_time_last_6_month', 'consume_top_time_last_1_month',
       'consume_top_time_last_6_month', 'cross_consume_count_last_1_month', 'trans_fail_top_count_enum_last_1_month',
       'trans_fail_top_count_enum_last_6_month', 'trans_fail_top_count_enum_last_12_month', 'consume_mini_time_last_1_month',
       'max_consume_count_later_6_month', 'railway_consume_count_last_12_month',
       'jewelry_consume_count_last_6_month', 'status', 'first_transaction_day',  'trans_day_last_12_month', 'apply_score', 'apply_credibility',
       'query_org_count', 'query_finance_count', 'query_cash_count', 'query_sum_count', 'latest_one_month_apply', 'latest_three_month_apply',
       'latest_six_month_apply', 'loans_score', 'loans_credibility_behavior', 'loans_count', 'loans_settle_count', 'loans_overdue_count',
       'loans_org_count_behavior', 'consfin_org_count_behavior', 'loans_cash_count', 'latest_one_month_loan', 'latest_three_month_loan',
       'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee','latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time',
       'loans_credit_limit', 'loans_credibility_limit', 'loans_org_count_current', 'loans_product_count', 'loans_max_limit',
       'loans_avg_limit', 'consfin_credit_limit', 'consfin_credibility', 'consfin_org_count_current', 'consfin_product_count',
       'consfin_max_limit', 'consfin_avg_limit', 'latest_query_day', 'loans_latest_day']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 85 columns):
# reg_preference_for_trad                       4754 non-null int64
# id_name                                       4754 non-null int64
# latest_query_time                             4754 non-null datetime64[ns]
# loans_latest_time                             4754 non-null datetime64[ns]
# take_amount_in_later_12_month_highest         4754 non-null int64
# is_high_user                                  4754 non-null int64
# historical_trans_amount                       4754 non-null int64
# trans_amount_3_month                          4754 non-null int64
# abs                                           4754 non-null int64
# avg_price_last_12_month                       4754 non-null int64
# max_cumulative_consume_later_1_month          4754 non-null int64
# pawns_auctions_trusts_consume_last_1_month    4754 non-null int64
# ...

# %%
d2 = pd.read_csv('C:/Users/dell/Desktop/data_2.csv',encoding = 'gbk')
d2.status[d2.student_feature.isna()==True].value_counts()
# Out:
# 0    2254
# 1     744
# Name: status, dtype: int64

# %%
d2.status[d2.student_feature==1].value_counts()
# Out:
# 0    1306
# 1     448
# Name: status, dtype: int64

# %%
data.student_feature[d2.student_feature.isna()==True] = 0
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data.drop('status',axis = 1)

# %%
data.head()
# Out:
#    reg_preference_for_trad  id_name latest_query_time loans_latest_time  \
# 0                        0     3118        2018-04-25        2018-04-19
# 1                        0     1077        2018-05-03        2018-05-05
# 2                        0     2490        2018-05-05        2018-05-01
# 3                        1      136        2018-05-05        2018-05-03
# 4                        0     3421        2018-04-15        2018-01-07
#
#    take_amount_in_later_12_month_highest  is_high_user  \
# 0                                      0             0
# 1                                   2000             0
# 2                                      0             0
# 3                                   2000             0
# 4                                      0             0
#
#    historical_trans_amount  trans_amount_3_month    abs  \
# 0                   149050                 34030   3920
# 1                   302910                 10590   6950
# ...

# %% [markdown]
# #### 有些乱，说一下大体思路：首先是非数值型数据处理（object文本），drop三个字段，两个转换成datetime，两个用label处理。接着处理数值型，drop三个字段（两个无作用字段和一个标签字段）。剩下的字段该怎么处理还不太清楚。
